# %%
# !pip3 install pandas

# %%
import pandas as pd

# %%
# !pip3 install openpyxl

# %%
# 다나와 크롤링 결과 가져오기
data = pd.read_excel('./1_danawa_crawling_result.xlsx')
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상품명     400 non-null    object
#  1   스펙 목록   400 non-null    object
#  2   가격      400 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 9.5+ KB
#                                      상품명  \
# 0      LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571
# 1                            샤오미 드리미 V10
# 2                  삼성전자 제트 VS20T9218QDCC
# 3  샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 4                삼성전자 비스포크 제트 VS20A956A3
#
#                                                스펙 목록       가격
# 0  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 2중터보싸...  1149590
# 1  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 멀티싸이클론 /...   150390
# 2  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 싸이클론 ...   547040
# 3  차량용청소기 / 무선 / 흡입력: 16,800Pa / 최대출력: 120W / 헤파필...    60610
# 4  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 제트싸이클...   696760

# %%
data['상품명'][:10]
# Out:
# 0        LG전자 오브제컬렉션 코드제로 ThinQ A9S AO9571
# 1                              샤오미 드리미 V10
# 2                    삼성전자 제트 VS20T9218QDCC
# 3    샤오미 CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)
# 4                  삼성전자 비스포크 제트 VS20A956A3
# 5             샤오미 미지아 차량용 핸디 무선 청소기 (해외구매)
# 6                  샤오미 TROUVER TECH SOLO10
# 7                 일렉트로룩스 WELL Q6 WQ61-1OGG
# 8       샤오미 CLEANFLY 차량용 무선 청소기 3세대 (해외구매)
# 9                        카렉스 파워스톰 미니 무선청소기
# Name: 상품명, dtype: object

# %%
# 회사명 + 모델명 분리
title = "LG전자 코드제로 A9 A978"
info = title.split(' ', 1)
print(info)
# Out:
# ['LG전자', '코드제로 A9 A978']

# %%
company_list = []
product_list=[]
for title in data['상품명']:
    try:
        title_info = title.split(' ', 1)
        company_name = title_info[0]
        product_name = title_info[1]
        company_list.append(company_name)
        product_list.append(product_name)
    except:
        continue

# %%
print(len(data))
print(len(company_list))
print(company_list[:5])
print(len(product_list))
print(product_list[:5])
# Out:
# 400
# 400
# ['LG전자', '샤오미', '삼성전자', '샤오미', '삼성전자']
# 400
# ['오브제컬렉션 코드제로 ThinQ A9S AO9571', '드리미 V10', '제트 VS20T9218QDCC', 'CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)', '비스포크 제트 VS20A956A3']

# %%
# 스펙 목록 데이터 살펴보기
data['스펙 목록'][2]
# Out:
# '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 싸이클론 / 인버터모터 / 흡입력: 200W / 소비전력: 550W / [배터리] 분리형 / 리튬이온 / 충전시간: 3시간30분 / 사용시간: 1시간(개당) / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 알레르기인증(BAF) / 미세먼지인증(SLG) / 색상: 티탄+그레이 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1123x215mm'

# %%
print(data['스펙 목록'][2].split(' / '))
# Out:
# ['핸디/스틱청소기', '핸디+스틱형', '무선형', '흡입+걸레겸용', '[성능] 싸이클론', '인버터모터', '흡입력: 200W', '소비전력: 550W', '[배터리] 분리형', '리튬이온', '충전시간: 3시간30분', '사용시간: 1시간(개당)', '[필터] 헤파필터', '5단계여과', '[기능] 디스플레이표시창', '프리볼트', '[구성] 바닥', '물걸레', '솔형', '틈새', '연장툴', '거치대', '청정스테이션', '[부가] 먼지통용량: 0.5L', '알레르기인증(BAF)', '미세먼지인증(SLG)', '색상: 티탄+그레이', '무게: 2.64kg', '크기(가로x세로x깊이): 250x1123x215mm']

# %%
# 첫 번째 제품의 스펙 목록 분리
spec_list = data['스펙 목록'][0].split(' / ')
spec_list
# Out:
# ['핸디/스틱청소기',
#  '핸디+스틱형',
#  '무선형',
#  '흡입+걸레겸용',
#  '[성능] 2중터보싸이클론',
#  '스마트인버터모터',
#  '흡입력: 210W',
#  '소비전력: 590W',
#  '[배터리] 분리형',
#  '리튬이온 (2개)',
#  '충전시간: 4시간',
#  '사용시간: 1시간(개당)',
#  '[필터] 헤파필터',
#  'H13급',
#  '5단계여과',
#  '[기능] 자동물공급',
#  '배터리잔량표시',
#  'IoT기능',
#  '[구성] 바닥',
#  '물걸레',
#  '침구',
#  '솔형',
#  '틈새',
#  '올인원타워',
#  '[부가] 알레르기인증(BAF)',
#  '미세먼지인증(SLG)',
#  '색상: 카밍베이지',
#  '무게: 2.6kg',
#  '분리형배기필터',
#  '먼지통자동비움',
#  '크기(가로x세로x깊이): 250x1120x260mm']

# %%
# 카테고리 정보 추출
category = spec_list[0]
category
# Out:
# '핸디/스틱청소기'

# %%
# '사용시간', '흡입력'이 포함된 원소 추출
for spec in spec_list:
    # spec_list에 있는 임의 셀 선택
    if '사용시간' in spec:
        use_time_spec = spec
    elif '흡입력' in spec:
        suction_spec = spec
        
print(use_time_spec)
print(suction_spec)
# Out:
# 사용시간: 1시간(개당)
# 흡입력: 210W

# %%
# 정량적인 수치 추출
use_time_value = use_time_spec.split(' ')[1].strip()
suction_value = suction_spec.split(' ')[1].strip()

print(use_time_value)
print(suction_value)
# Out:
# 1시간(개당)
# 210W

# %%
# 카테고리, 사용시간, 흡입력 추출
category_list = []
use_time_list = []
suction_list = []

for spec_data in data['스펙 목록']:
    print(spec_data)
    # ' / ' 기준으로 스펙 분리하기
    spec_list = spec_data.split(' / ')
    
    # 카테고리 추출하기
    category = spec_list[0]
    category_list.append(category)
    
    # 사용시간, 흡입력 추출
    ## 사용시간, 흡입력 정보가 없는 제품을 위해 변수를 생성
    use_time_value = None
    suction_value = None
    
    ## spec_list의 각 원소에서 사용시간, 흡입력 수치 추출
    for spec in spec_list:
        if '사용시간' in spec:
            use_time_value = spec.split(':')[1].strip()
        if '흡입력' in spec:
            suction_value = spec.split(':')[1].strip()
            
    use_time_list.append(use_time_value)
    suction_list.append(suction_value)
# Out:
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 2중터보싸이클론 / 스마트인버터모터 / 흡입력: 210W / 소비전력: 590W / [배터리] 분리형 / 리튬이온 (2개) / 충전시간: 4시간 / 사용시간: 1시간(개당) / [필터] 헤파필터 / H13급 / 5단계여과 / [기능] 자동물공급 / 배터리잔량표시 / IoT기능 / [구성] 바닥 / 물걸레 / 침구 / 솔형 / 틈새 / 올인원타워 / [부가] 알레르기인증(BAF) / 미세먼지인증(SLG) / 색상: 카밍베이지 / 무게: 2.6kg / 분리형배기필터 / 먼지통자동비움 / 크기(가로x세로x깊이): 250x1120x260mm
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입전용 / [성능] 멀티싸이클론 / BLDC모터 / 흡입력: 140AW / 흡입력: 22000Pa / 소비전력: 450W / [배터리] 용량: 2500mAh / 충전시간: 3시간30분 / 사용시간: 1시간(개당) / [필터] 헤파필터 / H12급 / 5단계여과 / [구성] 바닥 / 침구 / 솔형 / 틈새 / 연장툴 / 거치대 / [부가] 먼지통용량: 0.5L / 색상: 화이트 / 무게: 1.5kg
# 핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 흡입+걸레겸용 / [성능] 싸이클론 / 인버터모터 / 흡입력: 200W / 소비전력: 550W / [배터리] 분리형 / 리튬이온 / 충전시간: 3시간30분 / 사용시간: 1시간(개당) / [필터] 헤파필터 / 5단계여과 / [기능] 디스플레이표시창 / 프리볼트 / [구성] 바닥 / 물걸레 / 솔형 / 틈새 / 연장툴 / 거치대 / 청정스테이션 / [부가] 먼지통용량: 0.5L / 알레르기인증(BAF) / 미세먼지인증(SLG) / 색상: 티탄+그레이 / 무게: 2.64kg / 크기(가로x세로x깊이): 250x1123x215mm
# ...

# %%
# 카테고리, 사용시간, 흡입력에 대한 전처리 결과 확인
print("카테고리", len(category_list), category_list[0:8])
print("사용시간", len(use_time_list), use_time_list[0:8])
print("흡입력", len(suction_list), suction_list[0:8])
# Out:
# 카테고리 400 ['핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기']
# 사용시간 400 ['1시간(개당)', '1시간(개당)', '1시간(개당)', '30분', '1시간(개당)', '9~30분', '48분(개당)', '45분(개당)']
# 흡입력 400 ['210W', '22000Pa', '200W', '16,800Pa', '210W', '13,000Pa', '18000Pa', None]

# %%
use_time_list
# Out:
# ['1시간(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '30분',
#  '1시간(개당)',
#  '9~30분',
#  '48분(개당)',
#  '45분(개당)',
#  '25분',
#  '17분',
#  '1시간(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '1시간10분(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '30분',
#  '48분(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '40분(개당)',
#  '40분(개당)',
#  '1시간(개당)',
#  '53분(개당)',
#  '48분(개당)',
#  '45분',
#  '30분(개당)',
#  '1시간(개당)',
#  '최대 60분',
#  '40분(개당)',
#  None,
#  '1시간(개당)',
#  '1시간40분(개당)',
#  None,
#  '1시간(개당)',
#  '50분(개당)',
#  '1시간(개당)',
#  '60분(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '25분(개당)',
#  '1시간30분(개당)',
#  '50분(개당)',
#  '15~28분',
#  '1시간(개당)',
#  '1시간30분(개당)',
#  '50분(개당)',
#  '1시간(개당)',
#  '30분(개당)',
#  None,
#  None,
#  '20분(개당)',
#  '53분(개당)',
#  '50분(개당)',
#  '42분(개당)',
#  '48분(개당)',
#  '10분(개당)',
#  '40분(개당)',
#  '30분(개당)',
#  '18분',
#  '1시간(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '45분(개당)',
#  '60분',
#  '50분(개당)',
#  '15~30분',
#  '1시간(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
#  '1시간(개당)',
# ...

# %%
import numpy as np

# %%
# 사용시간을 분 단위로 조정하는 함수
def convert_time_minute(time):
    try:
        if '시간' in time:
            hour = time.split('시간')[0]
            
            if '분' in time:
                minute = time.split('시간')[-1].split('분')[0]

            else:
                minute = 0
        
        else:
            hour = 0
            
            if '~' in time:
                min_minute = time.split('~')[0]
                max_minute = time.split('~')[-1].split('분')[0]
                minute_mean_value = [int(min_minute), int(max_minute)]
                minute = np.mean(minute_mean_value)
                print(minute)
                
            else:
                minute = time.split('분')[0]
        return int(hour)*60 + int(minute)
    except:
        return None

# %%
# 사용시간을 분 단위로 조정하는 함수의 테스트
times = ["40분", "4분", "1시간", "3시간30분", "4시간", "9~30분"]
for time in times:
    time_value = convert_time_minute(time)
    print(time, "=", time_value)
# Out:
# 40분 = 40
# 4분 = 4
# 1시간 = 60
# 3시간30분 = 210
# 4시간 = 240
# 19.5
# 9~30분 = 19

# %%
# 모델별 사용시간을 분 단위로 통일하기
new_use_time_list = []
for time in use_time_list:
    value = convert_time_minute(time)
    new_use_time_list.append(value)
# Out:
# 19.5
# 21.5
# 22.5
# 25.0
# 12.5
# 7.5
# 19.0
# 13.5
# 18.0
# 16.0

# %%
print(len(new_use_time_list))
print(new_use_time_list[0:10])
# Out:
# 400
# [60, 60, 60, 30, 60, 19, 48, 45, 25, 17]

# %%
# 흡입력 단위를 통일시키는 함수
def get_suction(value):
    try:
        value = value.upper()
        if "AW" in value or "W" in value:
            result = value.replace("A", "").replace("W", "")
            result = int(result.replace(",", ""))
        elif "PA" in value:
            result = value.replace("PA", "")
            result = int(result.replace(",", ""))/100
        else:
            result = None
        return result
    except:
        return None

# %%
# 흡입력 함수 작동 테스트
suction_test_list = ["100W", "10AW", "10,000Pa"]
for power in suction_test_list:
    value = get_suction(power)
    print(power, value)
# Out:
# 100W 100
# 10AW 10
# 10,000Pa 100.0

# %%
# 흡입력 단위 통일시키기
new_suction_list = []
for power in suction_list:
    value = get_suction(power)
    new_suction_list.append(value)

print(len(new_suction_list))
print(new_suction_list[:10])
# Out:
# 400
# [210, 220.0, 200, 168.0, 210, 130.0, 180.0, None, 168.0, 120.0]

# %%
# 전처리 데이터 확인
pd_data = pd.DataFrame()
pd_data['카테고리'] = category_list
pd_data['회사명'] = company_list
pd_data['제품'] = product_list
pd_data['가격'] = data['가격']
pd_data['사용시간'] = new_use_time_list
pd_data['흡입력'] = new_suction_list
pd_data.head(10)
# Out:
#        카테고리     회사명                                 제품       가격  사용시간    흡입력
# 0  핸디/스틱청소기    LG전자       오브제컬렉션 코드제로 ThinQ A9S AO9571  1149590  60.0  210.0
# 1  핸디/스틱청소기     샤오미                            드리미 V10   150390  60.0  220.0
# 2  핸디/스틱청소기    삼성전자                   제트 VS20T9218QDCC   547040  60.0  200.0
# 3    차량용청소기     샤오미  CLEANFLY 차량용 무선 청소기 4세대 H2 (해외구매)    60610  30.0  168.0
# 4  핸디/스틱청소기    삼성전자                 비스포크 제트 VS20A956A3   696760  60.0  210.0
# 5    차량용청소기     샤오미           미지아 차량용 핸디 무선 청소기 (해외구매)    36480  19.0  130.0
# 6  핸디/스틱청소기     샤오미                TROUVER TECH SOLO10    64500  48.0  180.0
# 7  핸디/스틱청소기  일렉트로룩스                  WELL Q6 WQ61-1OGG   152940  45.0    NaN
# 8    차량용청소기     샤오미     CLEANFLY 차량용 무선 청소기 3세대 (해외구매)    49800  25.0  168.0
# 9    차량용청소기     카렉스                      파워스톰 미니 무선청소기    76460  17.0  120.0

# %%
# 카테고리 분류 기준 및 데이터 개수 점검
pd_data['카테고리'].value_counts()
# Out:
# 핸디/스틱청소기    279
# 물걸레청소기       46
# 차량용청소기       44
# 욕실청소기        23
# 침구청소기         4
# 업소용청소기        3
# 진공청소기         1
# Name: 카테고리, dtype: int64

# %%
# 핸디/스틱청소기만 선택
pd_data_final = pd_data[pd_data['카테고리'].isin(['핸디/스틱청소기'])]
len(pd_data_final)
# Out:
# 279

# %%
# 엑셀로 저장
pd_data_final.to_excel('./2_danawa_data_final.xlsx', index=False)
